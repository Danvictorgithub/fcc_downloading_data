# %%
from datetime import datetime
import csv
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# Sitka Weather Data
path = Path('./sitka_weather_2021_full.csv')
lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader)

# %%
# Death Valley Weather Data
path2 = Path('./death_valley_2021_full.csv')
lines2 = path2.read_text().splitlines()

reader2 = csv.reader(lines2)
header_row2 = next(reader2)

# %%
# San Francisco Weather Data
path3 = Path('./san_francisco_weather_2021_full.csv')
lines3 = path3.read_text().splitlines()

reader3 = csv.reader(lines3)
header_row3 = next(reader3)

# %%
# Checks indexes for Sitka Weather Data
for index, column_header in enumerate(header_row):
    print(index,column_header)
# Out:
# 0 STATION
# 1 NAME
# 2 DATE
# 3 AWND
# 4 PGTM
# 5 PRCP
# 6 TAVG
# 7 TMAX
# 8 TMIN
# 9 WDF2
# 10 WDF5
# 11 WSF2
# 12 WSF5
# 13 WT01
# 14 WT02
# 15 WT04
# 16 WT05
# 17 WT08
# 18 WT09

# %%
# Checks indexes for Death Valley Weather Data
for index, column_header in enumerate(header_row2):
    print(index,column_header)
# Out:
# 0 STATION
# 1 NAME
# 2 DATE
# 3 PRCP
# 4 SNOW
# 5 SNWD
# 6 TMAX
# 7 TMIN
# 8 TOBS

# %%
# Checks indexes for San Francisco Weather Data
for index, column_header in enumerate(header_row3):
    print(index,column_header)
# Out:
# 0 STATION
# 1 NAME
# 2 DATE
# 3 AWND
# 4 PRCP
# 5 SNOW
# 6 SNWD
# 7 TAVG
# 8 TMAX
# 9 TMIN
# 10 WDF2
# 11 WDF5
# 12 WSF2
# 13 WSF5
# 14 WT01
# 15 WT02
# 16 WT03
# 17 WT08

# %%
dates, highs = [], []
dates2, highs2 = [], []
dates3, highs3 = [], []

for row in reader:
    current_date = datetime.strptime(row[2], '%Y-%m-%d')
    try:
        high = int(row[7])
    except ValueError:
        print(f'No Data for {current_date}')
    else:
        dates.append(current_date)
        highs.append(high)
for row in reader2:
    current_date = datetime.strptime(row[2], '%Y-%m-%d')
    try:
        high = int(row[7])
    except ValueError:
        print(f'No Data for {current_date}')
    else:
        dates2.append(current_date)
        highs2.append(high)
for row in reader3:
    current_date = datetime.strptime(row[2], '%Y-%m-%d')
    try:
        high = int(row[8])
    except ValueError:
        print(f'No Data for {current_date}')
    else:
        dates3.append(current_date)
        highs3.append(high)
# Out:
# No Data for 2021-04-23 00:00:00

# %%
fig, ax = plt.subplots()
ax.plot(dates,highs,color='red')
ax.plot(dates2,highs2,color='blue')
ax.plot(dates3,highs3,color='green')

ax.set_title('Temperature Data in Sitka and Death Valley 2021')
ax.set_ylabel("Temperature in (F)",fontsize=16)
ax.set_xlabel("Date")
ax.legend(['Sitka Temperature', 'Death Valley','San Francisco'])
fig.autofmt_xdate()

plt.show()
